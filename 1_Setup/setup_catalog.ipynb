# %%
# %sql
CREATE CATALOG IF NOT EXISTS goods_ct;
USE CATALOG goods_ct;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS goods_ct.gold;
Create schema if not exists goods_ct.silver;
Create schema if not exists goods_ct.bronze;
